# %% [markdown]
# ## Encapsulation

# %%
class Atm:
  
  def __init__(self):
    
    self.__pin = ''
    self.__balance = 0
    self.__menu()

  def __menu(self):
    user_input = input('''
                  Hello, how would you like to proceed?
                  1. Enter 1 to create pin
                  2. Enter 2 to deposit
                  3. Enter 3 to withdraw
                  4. Enter 4 to check balance
                  5. Enter 5 to exit
    
    ''')
    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.deposit()
    elif user_input == '3':
      self.withdraw()
    elif user_input == '4':
      self.check_balance()
    else:
      print("bye")

  def create_pin(self):
    self.__pin = input('Enter your pin: ')
    print("PIN  set successfully")
    self.__menu()

  def deposit(self):
    temp = input("Enter your pin: ")
    if temp == self.__pin:
      amount = int(input("Enter the amount: "))
      self.__balance = self.__balance + amount
      print("Deposit successful")
    else:
      print("Invalid PIN")
    self.__menu()

  def withdraw(self):
    temp = input("Enter your pin: ")
    if temp == self.__pin:
      amount = int(input("Enter the amount: "))
      if amount < self.__balance:
        self.__balance = self.__balance - amount
        print("Operation successful")
      else:
        print("Insufficient Funds")
    else:
      print("Invalid PIN")  
    self.__menu()

  def check_balance(self):
    temp = input("Enter your pin: ")
    if temp == self.__pin:
      print(self.__balance)
    else:
      print("Invalid pin")
    self.__menu()

# %%
sbi = Atm()
# Out:
#                   Hello, how would you like to proceed?
#                   1. Enter 1 to create pin
#                   2. Enter 2 to deposit
#                   3. Enter 3 to withdraw
#                   4. Enter 4 to check balance
#                   5. Enter 5 to exit
#
#     1
# Enter your pin: 1234
# PIN  set successfully
#
#                   Hello, how would you like to proceed?
#                   1. Enter 1 to create pin
#                   2. Enter 2 to deposit
#                   3. Enter 3 to withdraw
#                   4. Enter 4 to check balance
#                   5. Enter 5 to exit
#
#     2
# Enter your pin: 1234
# Enter the amount: 50000
# Deposit successful
#
#                   Hello, how would you like to proceed?
#                   1. Enter 1 to create pin
#                   2. Enter 2 to deposit
#                   3. Enter 3 to withdraw
#                   4. Enter 4 to check balance
#                   5. Enter 5 to exit
#
#     5
# bye

# %%
sbi.check_balance()
# Out:
# Enter your pin: 1234
# 50000
#
#                   Hello, how would you like to proceed?
#                   1. Enter 1 to create pin
#                   2. Enter 2 to deposit
#                   3. Enter 3 to withdraw
#                   4. Enter 4 to check balance
#                   5. Enter 5 to exit
#
#     5
# bye

# %%
sbi.__balance = 60000

# %%
sbi.check_balance()
# Out:
# Enter your pin: 1234
# 50000
#
#                   Hello, how would you like to proceed?
#                   1. Enter 1 to create pin
#                   2. Enter 2 to deposit
#                   3. Enter 3 to withdraw
#                   4. Enter 4 to check balance
#                   5. Enter 5 to exit
#
#     5
# bye

# %% [markdown]
# - So when we are doing sbi.__balance, it is not accessing existing variable but creating a new varaible and not disturbing the existing logic.

# %% [markdown]
# ## Access Private Variable

# %%
sbi._Atm__balance
# Out:
# 50000

# %%
sbi._Atm__balance = 70000

# %%
sbi.check_balance()
# Out:
# Enter your pin: 1234
# 70000
#
#                   Hello, how would you like to proceed?
#                   1. Enter 1 to create pin
#                   2. Enter 2 to deposit
#                   3. Enter 3 to withdraw
#                   4. Enter 4 to check balance
#                   5. Enter 5 to exit
#
#     5
# bye

# %% [markdown]
# - From above syntax we can access any private variable and do whatever we want.
#
# - why everything in python is not completely private or protected, for this go to notes Day2

# %% [markdown]
# # Way to give access to private varaibles
#
# - Getter Method
#
# - Setter Method
#
# So Encapsulation concept is to hide data members of a class and not giving direct access to anyone but in future it may possible that those variables will be needed so for that we will be using getter and setter method to give access.
#
# Giving access with the help of getter and setter method is important because in this way we can use our logic through which anyone has to pass before making any changes and also only those changes will be allowed which we write in that setter method.
#
# So in this way we are not giving direct access to private variables and only allowing those changes which we decide in our logic by the help of getter and setter method.
#
# - So in a way we are protecting our data:
#  - if you want to see data, see with the help of function or method (get)
#  - if you want to set some value, set by going setter method by going through my logic
#
#
# - And that is the whole idea behind Encapsulation, for each data member we are making two method getter and setter. And these 3 together (data, getter, setter) has to make data work.
#
#
#
#
#
# ### This is Encapsulation.

# %%
class Atm:
  
  def __init__(self):
    
    self.__pin = ''
    self.__balance = 0
    self.__menu()

  def get_pin(self):
    return self.__pin

  def set_pin(self,new_pin):
    if type(new_pin) == str:
      self.__pin = new_pin
      print("Pin Changed")
    else:
      print("Not Allowed")

  def __menu(self):
    user_input = input('''
                  Hello, how would you like to proceed?
                  1. Enter 1 to create pin
                  2. Enter 2 to deposit
                  3. Enter 3 to withdraw
                  4. Enter 4 to check balance
                  5. Enter 5 to exit
    
    ''')
    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.deposit()
    elif user_input == '3':
      self.withdraw()
    elif user_input == '4':
      self.check_balance()
    else:
      print("bye")

  def create_pin(self):
    self.__pin = input('Enter your pin: ')
    print("PIN  set successfully")
    self.__menu()

  def deposit(self):
    temp = input("Enter your pin: ")
    if temp == self.__pin:
      amount = int(input("Enter the amount: "))
      self.__balance = self.__balance + amount
      print("Deposit successful")
    else:
      print("Invalid PIN")
    self.__menu()

  def withdraw(self):
    temp = input("Enter your pin: ")
    if temp == self.__pin:
      amount = int(input("Enter the amount: "))
      if amount < self.__balance:
        self.__balance = self.__balance - amount
        print("Operation successful")
      else:
        print("Insufficient Funds")
    else:
      print("Invalid PIN")  
    self.__menu()

  def check_balance(self):
    temp = input("Enter your pin: ")
    if temp == self.__pin:
      print(self.__balance)
    else:
      print("Invalid pin")
    self.__menu()

# %%
sbi = Atm()
# Out:
#                   Hello, how would you like to proceed?
#                   1. Enter 1 to create pin
#                   2. Enter 2 to deposit
#                   3. Enter 3 to withdraw
#                   4. Enter 4 to check balance
#                   5. Enter 5 to exit
#
#     1
# Enter your pin: 1234
# PIN  set successfully
#
#                   Hello, how would you like to proceed?
#                   1. Enter 1 to create pin
#                   2. Enter 2 to deposit
#                   3. Enter 3 to withdraw
#                   4. Enter 4 to check balance
#                   5. Enter 5 to exit
#
#     5
# bye

# %%
sbi.get_pin()
# Out:
# '1234'

# %%
sbi.set_pin(1234)
# Out:
# Not Allowed

# %%
sbi.set_pin("5678")
# Out:
# Pin Changed

# %%
sbi.get_pin()
# Out:
# '5678'
